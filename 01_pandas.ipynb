# %% [markdown]
# ## Pandas

# %% [markdown]
# ### File read write operation

# %%
import pandas as pd

# %%
draft1 = pd.read_csv("./datasets/housing/housing.csv")

# %%
draft1
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
type(draft1)
# Out:
# pandas.core.frame.DataFrame

# %%
draft1.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df1=pd.read_csv('mycsv.csv')
df1
# Out:
#       name empid                post   company    address
# 0  shivani   pqv  software developer  innodata      noida
# 1     abhi   abc                  SE   samsung    gurgaon
# 2     aman   xyz                  SE   qwalcom  hydrabaad
# 3    swati   sss             teacher       gov    bijnore

# %%
df1.head(2)
# Out:
#       name empid                post   company  address
# 0  shivani   pqv  software developer  innodata    noida
# 1     abhi   abc                  SE   samsung  gurgaon

# %%
df1.tail(2)
# Out:
#     name empid     post  company    address
# 2   aman   xyz       SE  qwalcom  hydrabaad
# 3  swati   sss  teacher      gov    bijnore

# %%
draft1 = pd.read_csv("./datasets/housing/housing.csv")
df2= draft1

# %%
df2 = pd.read_table('mytsv.tsv')

# %%
df2.head()
# Out:
#     name      empid    post      company     address
# 0  shivani   pqv      software  developer   innod...
# 1   abhi      abc      SE        samsung     gurgaon
# 2  aman      xyz      SE        qwalcom     hydra...
# 3  swati     sss      teacher   gov          bijnore

# %%
pd.read_table('mytsv.tsv',sep=',')
# Out:
#     name      empid    post      company     address
# 0  shivani   pqv      software  developer   innod...
# 1   abhi      abc      SE        samsung     gurgaon
# 2  aman      xyz      SE        qwalcom     hydra...
# 3  swati     sss      teacher   gov          bijnore

# %%
df2
# Out:
#     name      empid    post      company     address
# 0  shivani   pqv      software  developer   innod...
# 1   abhi      abc      SE        samsung     gurgaon
# 2  aman      xyz      SE        qwalcom     hydra...
# 3  swati     sss      teacher   gov          bijnore

# %%
pd.read_csv('mycsv.csv',header=None)
# Out:
#          0      1                   2         3          4
# 0     name  empid                post   company    address
# 1  shivani    pqv  software developer  innodata      noida
# 2     abhi    abc                  SE   samsung    gurgaon
# 3     aman    xyz                  SE   qwalcom  hydrabaad
# 4    swati    sss             teacher       gov    bijnore

# %%
df=pd.read_csv('mycsv.csv', names = ['col1','col2'])
df
# Out:
#                                       col1       col2
# name    empid post                 company    address
# shivani pqv   software developer  innodata      noida
# abhi     abc   SE                  samsung    gurgaon
# aman    xyz   SE                   qwalcom  hydrabaad
# swati   sss   teacher                  gov    bijnore

# %%
df=pd.read_csv('mycsv.csv', names = ['col1','col2','col3','col4','col5','cols6'])
df
# Out:
#       col1   col2                col3      col4       col5  cols6
# 0     name  empid                post   company    address    NaN
# 1  shivani    pqv  software developer  innodata      noida    NaN
# 2     abhi    abc                  SE   samsung    gurgaon    NaN
# 3     aman    xyz                  SE   qwalcom  hydrabaad    NaN
# 4    swati    sss             teacher       gov    bijnore    NaN

# %%
# !cat mycsv.csv  # for linux
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.

# %%
df = pd.read_csv('telecom.csv')
df
# Out:
#   company   area  connections company.1   address
# 0      vi  delhi            4      mzoo    Delhi2
# 1      vi  noida            5  innodata        GN
# 2     rel  delhi            4   qwalcom    Delhi1
# 3     rel  noida            5       gov  noidaExt
# 4  airtel  delhi            6     spice    Delhi6

# %% [markdown]
# ### Hierarchical Indexing

# %%
df = pd.read_csv('telecom.csv',index_col=['company'])
df
# Out:
#           area  connections company.1   address
# company
# vi       delhi            4      mzoo    Delhi2
# vi       noida            5  innodata        GN
# vi         sre            5     local        AV
# rel      delhi            4   qwalcom    Delhi1
# rel      noida            5       gov  noidaExt
# airtel   delhi            6     spice    Delhi6

# %%
df = pd.read_csv('telecom.csv',index_col=['company','area'])
df
# Out:
#                connections  company1   address
# company area
# vi      delhi            4      mzoo    Delhi2
#         noida            5  innodata        GN
#         sre              5     local        AV
# rel     delhi            4   qwalcom    Delhi1
#         noida            5       gov  noidaExt
# airtel  delhi            6     spice    Delhi6

# %% [markdown]
# ### Unformatted data

# %%
pd.read_csv('data.csv',skiprows=[1,3])
# Out:
#                              company   area  connections company1   address
# 0                                 vi  delhi          4.0     mzoo    Delhi2
# 1                                 vi    sre          5.0    local        AV
# 2                                rel  delhi          4.0  qwalcom    Delhi1
# 3  #this is comments related to data    NaN          NaN      NaN       NaN
# 4                                rel  noida          5.0      gov  noidaExt
# 5                             airtel  delhi          6.0    spice    Delhi6

# %%
pd.read_csv('data.csv',skiprows=[1,3,6])
# Out:
#   company   area  connections company1   address
# 0      vi  delhi            4     mzoo    Delhi2
# 1      vi    sre            5    local        AV
# 2     rel  delhi            4  qwalcom    Delhi1
# 3     rel  noida            5      gov  noidaExt
# 4  airtel  delhi            6    spice    Delhi6

# %%
res =pd.read_csv('data1.csv')
res
# Out:
#   company   area  connections company1   address
# 0      vi  delhi          4.0     mzoo    Delhi2
# 1      vi    sre          5.0    local        AV
# 2     rel  delhi          4.0  qwalcom    Delhi1
# 3     rel  noida          NaN      gov  noidaExt
# 4  airtel  delhi          6.0    spice    Delhi6

# %%
pd.isnull(res)
# Out:
#    company   area  connections  company1  address
# 0    False  False        False     False    False
# 1    False  False        False     False    False
# 2    False  False        False     False    False
# 3    False  False         True     False    False
# 4    False  False        False     False    False

# %% [markdown]
# ### working with Excel

# %%
df3 = pd.read_excel('data.xlsx')
df3
# Out:
#         date      time  pass          menu  meeting hours
# 0 2021-11-03       NaN   NaN           tea            3.0
# 1        NaT  12:30:00   1.0      buiskets            3.0
# 2        NaT       NaN   NaN        salate            NaN
# 3 2021-01-04  11:40:00   0.0   continental            3.0
# 4 2021-06-04       NaN   NaN  south indian            5.0
# 5        NaT  02:55:00   1.0       italian            NaN

# %%
df3 = pd.read_excel('data.xlsx' , sheet_name='xyz')
df3
# Out:
#        date1     time1  pass1         menu1  meeting hours1
# 0 2021-11-03       NaN     --           tea               3
# 1        NaT  12:30:00   True      buiskets               3
# 2        NaT       NaN    NaN        salate               0
# 3 2021-01-04  11:40:00  False   continental               3
# 4 2021-06-04       NaN    NaN  south indian               5
# 5        NaT  02:55:00   True       italian               0

# %% [markdown]
# ### Read Data from html

# %%
url = "http://www.basketball-reference.com/leagues/NBA_2015_totals.html" 

data = pd.read_html(url)
type(data)
# Out:
# list

# %%
type(data[0])
# Out:
# pandas.core.frame.DataFrame

# %%
data[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df = data[0]

# %%
df.tail(10)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 665  485  Brandan Wright  PF  27  PHO  40   7   858  120  207  ...  .667   70
# 666  486   Dorell Wright  SF  29  POR  48   2   592   72  190  ...  .810   14
# 667  487     Tony Wroten  PG  21  PHI  30  15   895  175  434  ...  .667   22
# 668  488     James Young  SG  19  BOS  31   0   332   36  102  ...  .552    9
# 669  489      Nick Young  SG  29  LAL  42   0  1000  174  476  ...  .892   17
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 665  124  194   23   32  47   16   54   280
# ...

# %% [markdown]
# ### Reading Columns

# %%
df['MP'] #reading column
# Out:
# 0      1287
# 1       248
# 2      1771
# 3       215
# 4      2502
#        ...
# 670    2434
# 671    1605
# 672     829
# 673    1487
# 674    1731
# Name: MP, Length: 675, dtype: object

# %%
df['MP','Tm'] #
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('MP', 'Tm')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-1567affc4840> in <module>
# ...

# %%
df[['MP','Tm']] # reading multiple column
# Out:
#        MP   Tm
# 0    1287  NYK
# 1     248  MEM
# 2    1771  OKC
# 3     215  MIN
# 4    2502  TOT
# ..    ...  ...
# 670  2434  TOT
# 671  1605  MIN
# 672   829  BRK
# 673  1487  CHO
# 674  1731  BOS
#
# [675 rows x 2 columns]

# %% [markdown]
# ### Series

# %%
type(df['MP'])
# Out:
# pandas.core.series.Series

# %%
type(df[['MP']])
# Out:
# pandas.core.frame.DataFrame

# %%
#url ="https://gist.github.com/michhar/2dfd2de0d4f8727f873422c5d959fff5#file-titanic-csv"
url = "https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/"

titanic_train= pd.read_csv(url)
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
#url = "https://gist.github.com/michhar/2dfd2de0d4f8727f873422c5d959fff5#file-titanic-csv"
titanic_train= pd.read_csv(url,',')

# %% [markdown]
# titanic_train.dtypes

# %% [markdown]
# ### Json

# %%
obj ='''"employees":[{ "firstName":"John", "lastName":"Doe" },  { "firstName":"Anna", "lastName":"Smith" },  { "firstName":"Peter", "lastName":"Jones" }]"'''
